# %%
import pandas as pd
import csv
import seaborn as sns

# %%
df = pd.read_csv("AIRBNB_DATA.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Part 1: Use this CSV of AirBNB data from NYC [original source]

# Use some of the cleaning techniques we used this week: write in a comment 
# what could be some uses for this dataset (1pt)

# There are many uses for this dataset and some come to mind almost immediately. I think property owners
# could use this data to see which borough is in the highest demand, for example. Another use that comes to mind
# is using the price and availabilty columns of this dataset in order to estimate the average price and/or highest
# willingness to pay for properties that may be similar to yours. That gives a good idea of what you can charge
# and what people are willing to pay per night if you are looking to rent out a property.

# %%
# use a seaborn map to find all the NaN values (1pt)

cols = df.columns
sns.heatmap(df[cols].isnull())
# Out:
# <AxesSubplot:>

# %%
# replace those NaN values (1pt)
df_copy = df.copy()
df_copy["last_review"] = df_copy["last_review"].fillna("Not Specified")
df_copy["reviews_per_month"] = df_copy["reviews_per_month"].fillna("Not Specified")
df_copy
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# isolate just the year from the last_review column (1pt)
df_copy.last_review = df_copy.last_review.str[0:4]
df_copy.last_review
for x in df_copy.last_review:
    if x == "Not ":
        continue
    else:
        print(x)
# Out:
# 2018
# 2019
# 2019
# 2018
# 2019
# 2017
# 2019
# 2017
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2019
# 2019
# 2019
# 2011
# 2019
# 2019
# 2019
# 2019
# 2019
# 2017
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2017
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2019
# 2017
# 2019
# 2017
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2016
# 2018
# 2019
# 2016
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2019
# 2018
# 2019
# 2018
# 2019
# 2019
# 2012
# 2019
# 2019
# 2018
# 2019
# 2018
# 2019
# 2017
# 2019
# 2019
# 2017
# 2018
# 2017
# 2015
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2011
# 2018
# 2011
# 2017
# 2017
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2017
# 2018
# 2016
# 2011
# 2019
# 2019
# 2019
# ...

# %%
# and do one other thing with the dataset of your choosing (1pt)
neighborhoods = df_copy["neighbourhood"]

list_of_neighborhoods = []
for x in neighborhoods:
    if x not in list_of_neighborhoods:
        list_of_neighborhoods.append(x)

print(list_of_neighborhoods)

# prints a list of all the neighborhoods with no repeat values
# Out:
# ['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem', 'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen", 'Upper West Side', 'Chinatown', 'South Slope', 'West Village', 'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights', 'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village', 'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side', 'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay', 'SoHo', 'Upper East Side', 'Prospect Heights', 'Washington Heights', 'Woodside', 'Brooklyn Heights', 'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill', 'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George', 'Highbridge', 'Financial District', 'Ridgewood', 'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo', 'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island', 'Greenwich Village', 'Little Italy', 'East Flatbush', 'Tompkinsville', 'Astoria', 'Clason Point', 'Eastchester', 'Kingsbridge', 'Two Bridges', 'Queens Village', 'Rockaway Beach', 'Fores
# ...

# %%
# Part 2: Try and create your own parser for an API. If you are using an API for your project, 
# build one for it; if you are not, choose an API that makes sense to you or is related to your project
# in some way. Include at least five functions for 1pt each. 

import requests
import json
import nltk

nltk.download("punkt")

text = """Some say the world will end in fire, Some say in ice. From what I’ve tasted of desire, I hold with those who favor fire. But if it had to perish twice, I think I know enough of hate, To know that for destruction ice Is also great, And would suffice."""
from nltk.tokenize import word_tokenize
tokenized_word = (word_tokenize(text))
print(tokenized_word)

# the word_tokenize function puts the text into a list where each word is an index
# Out:
# ['Some', 'say', 'the', 'world', 'will', 'end', 'in', 'fire', ',', 'Some', 'say', 'in', 'ice', '.', 'From', 'what', 'I', '’', 've', 'tasted', 'of', 'desire', ',', 'I', 'hold', 'with', 'those', 'who', 'favor', 'fire', '.', 'But', 'if', 'it', 'had', 'to', 'perish', 'twice', ',', 'I', 'think', 'I', 'know', 'enough', 'of', 'hate', ',', 'To', 'know', 'that', 'for', 'destruction', 'ice', 'Is', 'also', 'great', ',', 'And', 'would', 'suffice', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rishiheggawadi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize
print(sent_tokenize(text))
#sent_tokenize breaks up the text into sentences
# Out:
# ['Some say the world will end in fire, Some say in ice.', 'From what I’ve tasted of desire, I hold with those who favor fire.', 'But if it had to perish twice, I think I know enough of hate, To know that for destruction ice Is also great, And would suffice.']

# %%
from nltk.probability import FreqDist
fd = FreqDist(tokenized_word)
print(fd.most_common(3))

# finds the most common words being used (i set the limit to three in this case)
# Out:
# [(',', 5), ('I', 4), ('.', 3)]

# %%
import matplotlib.pyplot as plt
fd.plot(30, cumulative=False)
plt.show()

# plots the words and how many times they occur

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)

# prints a list of common stop-words, which could help in recognizing commonly used words to include or exclude
# Out:
# {'and', 'm', 'yours', 'other', 'too', 'hadn', 'hers', 'against', "didn't", 'don', 'or', 'between', 'about', 'then', 'will', "weren't", 'own', 'above', 'all', 'nor', 'very', "should've", 're', 'have', 't', "isn't", 'shouldn', "that'll", "shan't", "mustn't", 'to', 'some', 'has', 'mustn', 'who', 'after', 'can', "she's", 'ours', 'when', 'me', 'where', 'needn', 'o', 'your', 'been', 'being', 'off', 'should', 'hasn', 'did', 'no', 'is', 'not', 'just', 'those', 'over', 'more', 'such', 'was', 'are', 'be', 'this', 'up', 'an', 'haven', "mightn't", 'here', 'her', 'during', 'doesn', "you'll", 'from', 'his', 'that', 'down', 'doing', 'ma', 'she', "hasn't", 'i', 'before', 'under', 'few', 'but', 'once', 'shan', 'yourselves', 'yourself', 'out', 'ourselves', 'do', 'themselves', 'isn', 'these', 'why', 'again', 'wouldn', "you'd", 'weren', 'which', "it's", 've', 'him', "doesn't", 'myself', 'had', 'the', 'by', 'than', 'we', 'does', 'll', 'same', 'most', 'their', 'wasn', 'until', "aren't", 'how', 'now', 'at'
# ...
